# %%
conda config --add channels conda-forge
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda config --set channel_priority strict
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install clouddrift
# Out:
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 26.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - clouddrift
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asciitree-0.3.3            |             py_2           6 KB  conda-forge
#     awkward-2.13.0             |     pyhcf101f3_0         529 KB  conda-forge
#     awkward-cpp-56             |  py313hcb059c8_2         494 KB  conda-forge
#     aws-c-auth-0.8.0           |      h8bc59a9_15          90 KB  conda-forge
#     aws-c-cal-0.8.1            |       hc8a0bd2_3          39 KB  conda-forge
#     aws-c-common-0.10.6        |       h5505292_0         217 KB  conda-forge
#     aws-c-compression-0.3.0    |       hc8a0bd2_5          18 KB  conda-forge
#     aws-c-event-stream-0.5.0   |      h54f970a_11          46 KB  conda-forge
#     aws-c-http-0.9.2           |       h96aa502_4         149 KB  conda-forge
#     aws-c-io-0.15.3            |       haba67d1_6         133 KB  conda-forge
#     aws-c-mqtt-0.11.0          |      h24f418c_12         131 KB  conda-forge
#     aws-c-s3-0.7.7             |       h1be5864_0          95 KB  conda-forge
#     aws-c-sdkutils-0.2.1       |       hc8a0bd2_4          48 KB  conda-forge
#     aws-checksums-0.2.2        |       hc8a0bd2_4          69 KB  conda-forge
#     aws-crt-cpp-0.29.7         |       h19a973c_7         231 KB  conda-forge
#     aws-sdk-cpp-1.11.458       |       he0ff2e4_4         2.7 MB  conda-forge
#     azure-core-cpp-1.14.0      |       hd50102c_0         287 KB  conda-forge
#     azure-identity-cpp-1.10.0  |       hc602bab_0         163 KB  conda-forge
#     azure-storage-blobs-cpp-12.13.0|       h7585a09_1         428 KB  conda-forge
#     azure-storage-common-cpp-12.8.0|       h9ca1f76_1         118 KB  conda-forge
#     azure-storage-files-datalake-cpp-12.12.0|       hcdd55da_1         191 KB  conda-forge
#     blosc-1.21.6               |       h5499902_0          32 KB  conda-forge
#     boost-cpp-1.85.0           |       h103c1d6_4          18 KB  conda-forge
#     c-ares-1.34.8              |       h74c22ad_2         193 KB  conda-forge
#     ca-certificates-2026.7.22  |       hbd8a1cb_0         129 KB  conda-forge
#     cached-property-2.0.1      |     pyhcf101f3_0           4 KB  conda-forge
#     cached_property-2.0.1      |     pyhcf101f3_0          16 KB  conda-forge
#     certifi-2026.7.22          |     pyhd8ed1ab_0         134 KB  conda-forge
#     cftime-1.6.5               |  py313hb54f94e_2         403 KB  conda-forge
#     clouddrift-0.47.0          |     pyhd8ed1ab_0          97 KB  conda-forge
#     conda-25.7.0               |  py313h8f79df9_0         1.2 MB  conda-forge
#     curl-8.12.1                |       h73640d1_0         157 KB  conda-forge
#     cyrus-sasl-2.1.28          |       ha1cbb27_0         189 KB  conda-forge
#     fasteners-0.20             |     pyhd8ed1ab_0          25 KB  conda-forge
#     freetype-2.14.3            |       hce30654_2         171 KB  conda-forge
#     glib-2.84.0                |       heee381b_0         577 KB  conda-forge
#     glib-tools-2.84.0          |       h1dc7a0c_0          99 KB  conda-forge
#     glog-0.7.1                 |       heb240a5_0         110 KB  conda-forge
#     gst-plugins-base-1.24.11   |       h3c5c1d0_0         1.9 MB  conda-forge
#     gstreamer-1.24.11          |       hfe24232_0         1.3 MB  conda-forge
#     h5netcdf-1.8.1             |     pyhd8ed1ab_0          56 KB  conda-forge
#     h5py-3.13.0                |nompi_py313hcdf59df_100         1.2 MB  conda-forge
#     hdf4-4.2.15                |       h2ee6834_7         744 KB  conda-forge
#     hdf5-1.14.3                |nompi_ha698983_109         3.3 MB  conda-forge
#     icu-75.1                   |       hfee45f7_0        11.3 MB  conda-forge
#     krb5-1.21.3                |       h237132a_0         1.1 MB  conda-forge
#     lcms2-2.17                 |       h7eeda09_0         207 KB  conda-forge
#     libabseil-20240722.0       | cxx17_h07bc746_4         1.1 MB  conda-forge
#     libaec-1.1.5               |       h8664d51_0          30 KB  conda-forge
#     libarchive-3.7.7           |       h7c07d2a_0         759 KB  conda-forge
#     libarrow-18.1.0            |   h86d57b8_4_cpu         5.2 MB  conda-forge
#     libarrow-acero-18.1.0      |   h1dc2043_4_cpu         472 KB  conda-forge
#     libarrow-dataset-18.1.0    |   h1dc2043_4_cpu         478 KB  conda-forge
#     libarrow-substrait-18.1.0  |   hf3d3107_4_cpu         441 KB  conda-forge
#     libboost-1.85.0            |       hf763ba5_4         1.9 MB  conda-forge
#     libboost-devel-1.85.0      |       hf450f58_4          40 KB  conda-forge
#     libboost-headers-1.85.0    |       hce30654_4        13.5 MB  conda-forge
#     libbrotlicommon-1.1.0      |       h6caf38d_4          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       h6caf38d_4          28 KB  conda-forge
#     libbrotlienc-1.1.0         |       h6caf38d_4         269 KB  conda-forge
#     libclang-19.1.7            |default_hf3020a7_9          25 KB  conda-forge
#     libclang-cpp17-17.0.6      |default_hf90f093_8        12.2 MB  conda-forge
#     libclang13-19.1.7          |default_h13b06bd_9         8.0 MB  conda-forge
#     libcrc32c-1.1.2            |       hbdafb3b_0          18 KB  conda-forge
#     libcurl-8.12.1             |       h73640d1_0         379 KB  conda-forge
#     libcxx-23.1.1              |       h55c6f16_0         565 KB  conda-forge
#     libexpat-2.7.1             |       hec049ff_0          64 KB  conda-forge
#     libfreetype-2.14.3         |       hce30654_2           8 KB  conda-forge
#     libfreetype6-2.14.3        |       h2ed5691_2         333 KB  conda-forge
#     libgfortran-5.0.0          |14_2_0_h6c33f7e_103         153 KB  conda-forge
#     libgfortran5-14.2.0        |     h6c33f7e_103         788 KB  conda-forge
#     libglib-2.84.0             |       hdff4504_0         3.5 MB  conda-forge
#     libgoogle-cloud-2.31.0     |       h8d8be31_0         853 KB  conda-forge
#     libgoogle-cloud-storage-2.31.0|       h7081f7f_0         515 KB  conda-forge
#     libgrpc-1.67.1             |       hc70892a_0         4.7 MB  conda-forge
#     libiconv-1.18              |       he4c29f2_3         733 KB  conda-forge
#     libintl-0.25.1             |       h493aca8_0          89 KB  conda-forge
#     libintl-devel-0.25.1       |       h493aca8_0          39 KB  conda-forge
#     libjpeg-turbo-3.2.0        |       h84a0fba_1         545 KB  conda-forge
#     libllvm14-14.0.6           |       hd1a9a77_4        19.6 MB  conda-forge
#     libllvm17-17.0.6           |       hc4b4ae8_3        23.7 MB  conda-forge
#     libllvm19-19.1.7           |       hc4b4ae8_1        25.8 MB  conda-forge
#     libnetcdf-4.9.2            |nompi_h610d594_116         669 KB  conda-forge
#     libnghttp2-1.68.1          |       h435687b_1         554 KB  conda-forge
#     libntlm-1.8                |       h5505292_0          30 KB  conda-forge
#     libogg-1.3.5               |       h48c0fde_1         212 KB  conda-forge
#     libopus-1.6.1              |       h74c22ad_1         310 KB  conda-forge
#     libparquet-18.1.0          |   hf4cc9e7_4_cpu         853 KB  conda-forge
#     libpng-1.6.58              |       hf5e6511_1         283 KB  conda-forge
#     libpq-17.7                 |       h944245b_1         2.4 MB  conda-forge
#     libprotobuf-5.28.2         |       h8f0b736_0         2.3 MB  conda-forge
#     libre2-11-2024.07.02       |       h07bc746_2         163 KB  conda-forge
#     libsolv-0.7.39             |       h626c152_1         424 KB  conda-forge
#     libsqlite-3.51.1           |       h9a5124b_0         885 KB  conda-forge
#     libssh2-1.11.1             |       hbf2880b_1         274 KB  conda-forge
#     libthrift-0.21.0           |       h64651cc_0         317 KB  conda-forge
#     libtiff-4.7.0              |       hfce79cd_1         358 KB  conda-forge
#     libutf8proc-2.9.0          |       h5505292_1          81 KB  conda-forge
#     libvorbis-1.3.7            |       h81086ad_2         253 KB  conda-forge
#     libwebp-base-1.6.0         |       h202fb40_1         288 KB  conda-forge
#     libxcb-1.17.0              |       hbffa61f_2         317 KB  conda-forge
#     libxml2-2.13.5             |       hbbdcc80_0         569 KB  conda-forge
#     libzip-1.11.2              |       hcd2b5ac_1         125 KB  conda-forge
#     libzlib-1.3.2              |       h8088a28_3          47 KB  conda-forge
#     llvmlite-0.44.0            |  py313h9cecdfe_2        18.0 MB  conda-forge
#     mysql-9.0.1                |       h44b9a77_2         169 KB  conda-forge
#     mysql-client-9.0.1         |       he9bc4e1_2         4.3 MB  conda-forge
#     mysql-common-9.0.1         |       h0887d5e_2         616 KB  conda-forge
#     mysql-devel-9.0.1          |       h0887d5e_2         1.5 MB  conda-forge
#     mysql-libs-9.0.1           |       he9bc4e1_2         1.3 MB  conda-forge
#     mysql-server-9.0.1         |       h0f1b86c_2        16.8 MB  conda-forge
#     ncurses-6.6                |       he64c551_1         785 KB  conda-forge
#     netcdf4-1.7.2              |nompi_py313h543093b_101        1011 KB  conda-forge
#     nspr-4.40                  |       hdcbdcf5_0         198 KB  conda-forge
#     nss-3.118                  |       h1c710a3_0         1.8 MB  conda-forge
#     numcodecs-0.15.1           |  py313h7d16b84_1         647 KB  conda-forge
#     openldap-2.6.10            |       hbe55e7a_0         824 KB  conda-forge
#     openssl-3.6.4              |       h55eecbc_0         3.0 MB  conda-forge
#     orc-2.0.3                  |       h121fd32_0         428 KB  conda-forge
#     pcre2-10.44                |       ha881caa_2         607 KB  conda-forge
#     pillow-11.0.0              |  py313h97432e1_0        39.8 MB  conda-forge
#     protobuf-5.28.2            |  py313h4e5f155_0         443 KB  conda-forge
#     pthread-stubs-0.4          |    hb001647_1004           9 KB  conda-forge
#     pyarrow-18.1.0             |  py313h39782a4_0          25 KB  conda-forge
#     pyarrow-core-18.1.0        |py313hf9431ad_0_cpu         3.7 MB  conda-forge
#     pytables-3.10.2            |  py313h678a918_2         1.7 MB  conda-forge
#     python-3.13.1              |hbbac1ca_100_cp313        12.2 MB  conda-forge
#     qt-main-5.15.15            |       h67564f6_2        48.1 MB  conda-forge
#     re2-2024.07.02             |       h6589ca4_2          26 KB  conda-forge
#     sqlite-3.51.1              |       he8f07e4_0         162 KB  conda-forge
#     tk-8.6.13                  |       hbeba79b_4         3.2 MB  conda-forge
#     xorg-libxau-1.0.12         |       hb001647_2          17 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       h84a0fba_2          19 KB  conda-forge
#     zarr-2.18.7                |     pyhd8ed1ab_0         157 KB  conda-forge
#     zlib-1.3.2                 |       h8088a28_3          80 KB  conda-forge
#     zstd-1.5.6                 |       hb46c0d2_0         396 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       330.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   asciitree          conda-forge/noarch::asciitree-0.3.3-py_2
#   awkward            conda-forge/noarch::awkward-2.13.0-pyhcf101f3_0
#   awkward-cpp        conda-forge/osx-arm64::awkward-cpp-56-py313hcb059c8_2
#   azure-core-cpp     conda-forge/osx-arm64::azure-core-cpp-1.14.0-hd50102c_0
#   azure-identity-cpp conda-forge/osx-arm64::azure-identity-cpp-1.10.0-hc602bab_0
#   azure-storage-blo~ conda-forge/osx-arm64::azure-storage-blobs-cpp-12.13.0-h7585a09_1
#   azure-storage-com~ conda-forge/osx-arm64::azure-storage-common-cpp-12.8.0-h9ca1f76_1
#   azure-storage-fil~ conda-forge/osx-arm64::azure-storage-files-datalake-cpp-12.12.0-hcdd55da_1
#   cached-property    conda-forge/noarch::cached-property-2.0.1-pyhcf101f3_0
#   cached_property    conda-forge/noarch::cached_property-2.0.1-pyhcf101f3_0
#   cftime             conda-forge/osx-arm64::cftime-1.6.5-py313hb54f94e_2
#   clouddrift         conda-forge/noarch::clouddrift-0.47.0-pyhd8ed1ab_0
#   fasteners          conda-forge/noarch::fasteners-0.20-pyhd8ed1ab_0
#   h5netcdf           conda-forge/noarch::h5netcdf-1.8.1-pyhd8ed1ab_0
#   hdf4               conda-forge/osx-arm64::hdf4-4.2.15-h2ee6834_7
#   libaec             conda-forge/osx-arm64::libaec-1.1.5-h8664d51_0
#   libarrow           conda-forge/osx-arm64::libarrow-18.1.0-h86d57b8_4_cpu
#   libarrow-acero     conda-forge/osx-arm64::libarrow-acero-18.1.0-h1dc2043_4_cpu
#   libarrow-dataset   conda-forge/osx-arm64::libarrow-dataset-18.1.0-h1dc2043_4_cpu
#   libarrow-substrait conda-forge/osx-arm64::libarrow-substrait-18.1.0-hf3d3107_4_cpu
#   libboost-devel     conda-forge/osx-arm64::libboost-devel-1.85.0-hf450f58_4
#   libboost-headers   conda-forge/osx-arm64::libboost-headers-1.85.0-hce30654_4
#   libclang-cpp17     conda-forge/osx-arm64::libclang-cpp17-17.0.6-default_hf90f093_8
#   libcrc32c          conda-forge/osx-arm64::libcrc32c-1.1.2-hbdafb3b_0
#   libexpat           conda-forge/osx-arm64::libexpat-2.7.1-hec049ff_0
#   libfreetype        conda-forge/osx-arm64::libfreetype-2.14.3-hce30654_2
#   libfreetype6       conda-forge/osx-arm64::libfreetype6-2.14.3-h2ed5691_2
#   libgoogle-cloud    conda-forge/osx-arm64::libgoogle-cloud-2.31.0-h8d8be31_0
#   libgoogle-cloud-s~ conda-forge/osx-arm64::libgoogle-cloud-storage-2.31.0-h7081f7f_0
#   libintl            conda-forge/osx-arm64::libintl-0.25.1-h493aca8_0
#   libintl-devel      conda-forge/osx-arm64::libintl-devel-0.25.1-h493aca8_0
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.2.0-h84a0fba_1
#   libllvm17          conda-forge/osx-arm64::libllvm17-17.0.6-hc4b4ae8_3
#   libllvm19          conda-forge/osx-arm64::libllvm19-19.1.7-hc4b4ae8_1
#   libnetcdf          conda-forge/osx-arm64::libnetcdf-4.9.2-nompi_h610d594_116
#   libntlm            conda-forge/osx-arm64::libntlm-1.8-h5505292_0
#   libogg             conda-forge/osx-arm64::libogg-1.3.5-h48c0fde_1
#   libopus            conda-forge/osx-arm64::libopus-1.6.1-h74c22ad_1
#   libparquet         conda-forge/osx-arm64::libparquet-18.1.0-hf4cc9e7_4_cpu
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.51.1-h9a5124b_0
#   libutf8proc        conda-forge/osx-arm64::libutf8proc-2.9.0-h5505292_1
#   libvorbis          conda-forge/osx-arm64::libvorbis-1.3.7-h81086ad_2
#   libxcb             conda-forge/osx-arm64::libxcb-1.17.0-hbffa61f_2
#   libzip             conda-forge/osx-arm64::libzip-1.11.2-hcd2b5ac_1
#   libzlib            conda-forge/osx-arm64::libzlib-1.3.2-h8088a28_3
#   mysql-client       conda-forge/osx-arm64::mysql-client-9.0.1-he9bc4e1_2
#   mysql-common       conda-forge/osx-arm64::mysql-common-9.0.1-h0887d5e_2
#   mysql-devel        conda-forge/osx-arm64::mysql-devel-9.0.1-h0887d5e_2
#   mysql-libs         conda-forge/osx-arm64::mysql-libs-9.0.1-he9bc4e1_2
#   mysql-server       conda-forge/osx-arm64::mysql-server-9.0.1-h0f1b86c_2
#   netcdf4            conda-forge/osx-arm64::netcdf4-1.7.2-nompi_py313h543093b_101
#   nspr               conda-forge/osx-arm64::nspr-4.40-hdcbdcf5_0
#   nss                conda-forge/osx-arm64::nss-3.118-h1c710a3_0
#   numcodecs          conda-forge/osx-arm64::numcodecs-0.15.1-py313h7d16b84_1
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hb001647_1004
#   pyarrow-core       conda-forge/osx-arm64::pyarrow-core-18.1.0-py313hf9431ad_0_cpu
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.12-hb001647_2
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-h84a0fba_2
#   zarr               conda-forge/noarch::zarr-2.18.7-pyhd8ed1ab_0
#
# The following packages will be REMOVED:
#
#   arrow-cpp-19.0.0-h0b7d223_2
#   jpeg-9e-h80987f9_3
#
# The following packages will be UPDATED:
#
#   aws-c-auth         pkgs/main::aws-c-auth-0.6.19-h80987f9~ --> conda-forge::aws-c-auth-0.8.0-h8bc59a9_15
#   aws-c-cal          pkgs/main::aws-c-cal-0.5.20-h80987f9_0 --> conda-forge::aws-c-cal-0.8.1-hc8a0bd2_3
#   aws-c-common       pkgs/main::aws-c-common-0.8.5-h80987f~ --> conda-forge::aws-c-common-0.10.6-h5505292_0
#   aws-c-compression  pkgs/main::aws-c-compression-0.2.16-h~ --> conda-forge::aws-c-compression-0.3.0-hc8a0bd2_5
#   aws-c-event-stream pkgs/main::aws-c-event-stream-0.2.15-~ --> conda-forge::aws-c-event-stream-0.5.0-h54f970a_11
#   aws-c-http         pkgs/main::aws-c-http-0.6.25-h80987f9~ --> conda-forge::aws-c-http-0.9.2-h96aa502_4
#   aws-c-io           pkgs/main::aws-c-io-0.13.10-h80987f9_0 --> conda-forge::aws-c-io-0.15.3-haba67d1_6
#   aws-c-mqtt         pkgs/main::aws-c-mqtt-0.7.13-h80987f9~ --> conda-forge::aws-c-mqtt-0.11.0-h24f418c_12
#   aws-c-s3            pkgs/main::aws-c-s3-0.1.51-h80987f9_0 --> conda-forge::aws-c-s3-0.7.7-h1be5864_0
#   aws-c-sdkutils     pkgs/main::aws-c-sdkutils-0.1.6-h8098~ --> conda-forge::aws-c-sdkutils-0.2.1-hc8a0bd2_4
#   aws-checksums      pkgs/main::aws-checksums-0.1.13-h8098~ --> conda-forge::aws-checksums-0.2.2-hc8a0bd2_4
#   aws-crt-cpp        pkgs/main::aws-crt-cpp-0.18.16-h313be~ --> conda-forge::aws-crt-cpp-0.29.7-h19a973c_7
#   aws-sdk-cpp        pkgs/main::aws-sdk-cpp-1.11.212-hdd7f~ --> conda-forge::aws-sdk-cpp-1.11.458-he0ff2e4_4
#   blosc                  pkgs/main::blosc-1.21.3-h313beb8_0 --> conda-forge::blosc-1.21.6-h5499902_0
#   boost-cpp          pkgs/main::boost-cpp-1.82.0-h48ca7d4_2 --> conda-forge::boost-cpp-1.85.0-h103c1d6_4
#   c-ares                pkgs/main::c-ares-1.19.1-h80987f9_0 --> conda-forge::c-ares-1.34.8-h74c22ad_2
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-~ --> conda-forge/noarch::ca-certificates-2026.7.22-hbd8a1cb_0
#   certifi            pkgs/main/osx-arm64::certifi-2026.6.1~ --> conda-forge/noarch::certifi-2026.7.22-pyhd8ed1ab_0
#   conda              pkgs/main::conda-25.5.1-py313hca03da5~ --> conda-forge::conda-25.7.0-py313h8f79df9_0
#   freetype            pkgs/main::freetype-2.13.3-h47d26ad_0 --> conda-forge::freetype-2.14.3-hce30654_2
#   glib                    pkgs/main::glib-2.78.4-h313beb8_0 --> conda-forge::glib-2.84.0-heee381b_0
#   glib-tools         pkgs/main::glib-tools-2.78.4-h313beb8~ --> conda-forge::glib-tools-2.84.0-h1dc7a0c_0
#   glog                     pkgs/main::glog-0.5.0-h313beb8_1 --> conda-forge::glog-0.7.1-heb240a5_0
#   gst-plugins-base   pkgs/main::gst-plugins-base-1.14.1-h3~ --> conda-forge::gst-plugins-base-1.24.11-h3c5c1d0_0
#   gstreamer          pkgs/main::gstreamer-1.14.1-h80987f9_1 --> conda-forge::gstreamer-1.24.11-hfe24232_0
#   h5py               pkgs/main::h5py-3.12.1-py313h0957e0b_1 --> conda-forge::h5py-3.13.0-nompi_py313hcdf59df_100
#   icu                        pkgs/main::icu-73.1-h313beb8_0 --> conda-forge::icu-75.1-hfee45f7_0
#   krb5                    pkgs/main::krb5-1.20.1-hf3e1bf2_1 --> conda-forge::krb5-1.21.3-h237132a_0
#   lcms2                    pkgs/main::lcms2-2.16-he26ebf3_1 --> conda-forge::lcms2-2.17-h7eeda09_0
#   libboost            pkgs/main::libboost-1.82.0-h0bc93f9_2 --> conda-forge::libboost-1.85.0-hf763ba5_4
#   libbrotlicommon    pkgs/main::libbrotlicommon-1.0.9-h809~ --> conda-forge::libbrotlicommon-1.1.0-h6caf38d_4
#   libbrotlidec       pkgs/main::libbrotlidec-1.0.9-h80987f~ --> conda-forge::libbrotlidec-1.1.0-h6caf38d_4
#   libbrotlienc       pkgs/main::libbrotlienc-1.0.9-h80987f~ --> conda-forge::libbrotlienc-1.1.0-h6caf38d_4
#   libclang           pkgs/main::libclang-14.0.6-default_h1~ --> conda-forge::libclang-19.1.7-default_hf3020a7_9
#   libclang13         pkgs/main::libclang13-14.0.6-default_~ --> conda-forge::libclang13-19.1.7-default_h13b06bd_9
#   libcxx                pkgs/main::libcxx-14.0.6-h848a8c0_0 --> conda-forge::libcxx-23.1.1-h55c6f16_0
#   libgfortran        pkgs/main::libgfortran-5.0.0-11_3_0_h~ --> conda-forge::libgfortran-5.0.0-14_2_0_h6c33f7e_103
#   libgfortran5       pkgs/main::libgfortran5-11.3.0-h00934~ --> conda-forge::libgfortran5-14.2.0-h6c33f7e_103
#   libglib              pkgs/main::libglib-2.78.4-h0a96307_0 --> conda-forge::libglib-2.84.0-hdff4504_0
#   libiconv              pkgs/main::libiconv-1.16-h80987f9_3 --> conda-forge::libiconv-1.18-he4c29f2_3
#   libnghttp2         pkgs/main::libnghttp2-1.57.0-h62f6fdd~ --> conda-forge::libnghttp2-1.68.1-h435687b_1
#   libpng                pkgs/main::libpng-1.6.39-h80987f9_0 --> conda-forge::libpng-1.6.58-hf5e6511_1
#   libpq                    pkgs/main::libpq-17.4-h02f6b3c_0 --> conda-forge::libpq-17.7-h944245b_1
#   libre2-11          pkgs/main::libre2-11-2024.07.02-h313b~ --> conda-forge::libre2-11-2024.07.02-h07bc746_2
#   libsolv              pkgs/main::libsolv-0.7.30-h514c7bf_1 --> conda-forge::libsolv-0.7.39-h626c152_1
#   libssh2              pkgs/main::libssh2-1.11.1-h3e2b118_0 --> conda-forge::libssh2-1.11.1-hbf2880b_1
#   libthrift          pkgs/main::libthrift-0.15.0-h73c2103_2 --> conda-forge::libthrift-0.21.0-h64651cc_0
#   libtiff               pkgs/main::libtiff-4.7.0-h91aec0a_0 --> conda-forge::libtiff-4.7.0-hfce79cd_1
#   libwebp-base       pkgs/main::libwebp-base-1.3.2-h80987f~ --> conda-forge::libwebp-base-1.6.0-h202fb40_1
#   llvmlite           pkgs/main::llvmlite-0.44.0-py313heb35~ --> conda-forge::llvmlite-0.44.0-py313h9cecdfe_2
#   mysql                   pkgs/main::mysql-8.4.0-h065ec36_2 --> conda-forge::mysql-9.0.1-h44b9a77_2
#   ncurses                 pkgs/main::ncurses-6.4-h313beb8_0 --> conda-forge::ncurses-6.6-he64c551_1
#   openldap             pkgs/main::openldap-2.6.4-he7ef289_0 --> conda-forge::openldap-2.6.10-hbe55e7a_0
#   openssl               pkgs/main::openssl-3.5.7-ha0b305a_0 --> conda-forge::openssl-3.6.4-h55eecbc_0
#   pcre2                   pkgs/main::pcre2-10.42-hb066dcc_1 --> conda-forge::pcre2-10.44-ha881caa_2
#   qt-main             pkgs/main::qt-main-5.15.2-h0917680_12 --> conda-forge::qt-main-5.15.15-h67564f6_2
#   re2                  pkgs/main::re2-2024.07.02-h48ca7d4_0 --> conda-forge::re2-2024.07.02-h6589ca4_2
#   sqlite                pkgs/main::sqlite-3.45.3-h80987f9_0 --> conda-forge::sqlite-3.51.1-he8f07e4_0
#   zlib                    pkgs/main::zlib-1.2.13-h18a0788_1 --> conda-forge::zlib-1.3.2-h8088a28_3
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   curl                    pkgs/main::curl-8.12.1-h3e2b118_0 --> conda-forge::curl-8.12.1-h73640d1_0
#   cyrus-sasl         pkgs/main::cyrus-sasl-2.1.28-h9131b1a~ --> conda-forge::cyrus-sasl-2.1.28-ha1cbb27_0
#   hdf5                    pkgs/main::hdf5-1.14.5-hd77251f_2 --> conda-forge::hdf5-1.14.3-nompi_ha698983_109
#   libabseil          pkgs/main::libabseil-20250127.0-cxx17~ --> conda-forge::libabseil-20240722.0-cxx17_h07bc746_4
#   libarchive         pkgs/main::libarchive-3.7.7-h8f13d7a_0 --> conda-forge::libarchive-3.7.7-h7c07d2a_0
#   libcurl              pkgs/main::libcurl-8.12.1-hde089ae_0 --> conda-forge::libcurl-8.12.1-h73640d1_0
#   libgrpc              pkgs/main::libgrpc-1.71.0-h62f6fdd_0 --> conda-forge::libgrpc-1.67.1-hc70892a_0
#   libllvm14          pkgs/main::libllvm14-14.0.6-h19fdd8a_4 --> conda-forge::libllvm14-14.0.6-hd1a9a77_4
#   libprotobuf        pkgs/main::libprotobuf-5.29.3-h9f9f82~ --> conda-forge::libprotobuf-5.28.2-h8f0b736_0
#   libxml2              pkgs/main::libxml2-2.13.8-h0b34f26_0 --> conda-forge::libxml2-2.13.5-hbbdcc80_0
#   orc                       pkgs/main::orc-2.1.1-h55d209b_0 --> conda-forge::orc-2.0.3-h121fd32_0
#   pillow             pkgs/main::pillow-11.1.0-py313h41ba81~ --> conda-forge::pillow-11.0.0-py313h97432e1_0
#   protobuf           pkgs/main::protobuf-5.29.3-py313h514c~ --> conda-forge::protobuf-5.28.2-py313h4e5f155_0
#   pyarrow            pkgs/main::pyarrow-19.0.0-py313h313be~ --> conda-forge::pyarrow-18.1.0-py313h39782a4_0
#   pytables           pkgs/main::pytables-3.10.2-py313h8397~ --> conda-forge::pytables-3.10.2-py313h678a918_2
#   python             pkgs/main::python-3.13.5-h2eb94d5_100~ --> conda-forge::python-3.13.1-hbbac1ca_100_cp313
#   tk                        pkgs/main::tk-8.6.14-h6ba3021_1 --> conda-forge::tk-8.6.13-hbeba79b_4
#   zstd                     pkgs/main::zstd-1.5.6-hfb09047_0 --> conda-forge::zstd-1.5.6-hb46c0d2_0
#
#
#
# Downloading and Extracting Packages:
# qt-main-5.15.15      | 48.1 MB   |                                       |   0%
# pillow-11.0.0        | 39.8 MB   |                                       |   0%
#
# libllvm19-19.1.7     | 25.8 MB   |                                       |   0%
#
#
# libllvm17-17.0.6     | 23.7 MB   |                                       |   0%
#
#
#
# libllvm14-14.0.6     | 19.6 MB   |                                       |   0%
#
#
#
#
# llvmlite-0.44.0      | 18.0 MB   |                                       |   0%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   |                                       |   0%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   |                                       |   0%
#
#
#
#
#
#
#
# python-3.13.1        | 12.2 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.3 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-18.1.0      | 5.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 4.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.4        | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.7           | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# libllvm14-14.0.6     | 19.6 MB   | ###7                                  |  10%
#
#
#
# qt-main-5.15.15      | 48.1 MB   |                                       |   0%
#
# libllvm19-19.1.7     | 25.8 MB   |                                       |   0%
#
#
# libllvm17-17.0.6     | 23.7 MB   |                                       |   0%
# pillow-11.0.0        | 39.8 MB   |                                       |   0%
#
#
#
# libllvm14-14.0.6     | 19.6 MB   | ##############################6       |  83%
#
#
#
# libllvm14-14.0.6     | 19.6 MB   | ##################################### | 100%
#
#
# libllvm17-17.0.6     | 23.7 MB   | 4                                     |   1%
#
#
#
#
# llvmlite-0.44.0      | 18.0 MB   |                                       |   0%
#
# qt-main-5.15.15      | 48.1 MB   | 6                                     |   2%
#
#
# libllvm17-17.0.6     | 23.7 MB   | 7                                     |   2%
#
# libllvm19-19.1.7     | 25.8 MB   | #######8                              |  21%
#
#
#
#
# llvmlite-0.44.0      | 18.0 MB   | #######5                              |  21%
# qt-main-5.15.15      | 48.1 MB   | #1                                    |   3%
#
#
# libllvm17-17.0.6     | 23.7 MB   | #1                                    |   3%
#
# libllvm19-19.1.7     | 25.8 MB   | ###########1                          |  30%
#
#
#
#
# llvmlite-0.44.0      | 18.0 MB   | ################4                     |  44%
#
#
#
# libllvm14-14.0.6     | 19.6 MB   | ##################################### | 100%
# qt-main-5.15.15      | 48.1 MB   | #6                                    |   4%
#
# libllvm19-19.1.7     | 25.8 MB   | ##############9                       |  40%
#
#
# libllvm17-17.0.6     | 23.7 MB   | #6                                    |   4%
#
#
#
#
# llvmlite-0.44.0      | 18.0 MB   | #########################1            |  68%
# pillow-11.0.0        | 39.8 MB   | 2                                     |   1%
#
#
# libllvm17-17.0.6     | 23.7 MB   | ##3                                   |   6%
#
#
#
#
# llvmlite-0.44.0      | 18.0 MB   | ##################################    |  92%
#
# qt-main-5.15.15      | 48.1 MB   | ##                                    |   5%
#
#
#
#
# llvmlite-0.44.0      | 18.0 MB   | ##################################### | 100%
# pillow-11.0.0        | 39.8 MB   | 3                                     |   1%
#
#
# libllvm17-17.0.6     | 23.7 MB   | ###6                                  |  10%
#
# qt-main-5.15.15      | 48.1 MB   | ##6                                   |   7%
# pillow-11.0.0        | 39.8 MB   | 5                                     |   1%
#
#
# libllvm17-17.0.6     | 23.7 MB   | ####9                                 |  13%
#
# qt-main-5.15.15      | 48.1 MB   | ###5                                  |  10%
# pillow-11.0.0        | 39.8 MB   | 6                                     |   2%
#
#
# libllvm17-17.0.6     | 23.7 MB   | ######9                               |  19%
#
# libllvm19-19.1.7     | 25.8 MB   | ###################################5  |  96%
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ####4                                 |  12%
#
# libllvm19-19.1.7     | 25.8 MB   | ##################################### | 100%
# pillow-11.0.0        | 39.8 MB   | 9                                     |   3%
#
#
# qt-main-5.15.15      | 48.1 MB   | #####7                                |  16%
# pillow-11.0.0        | 39.8 MB   | #3                                    |   4%
#
#
# qt-main-5.15.15      | 48.1 MB   | #######6                              |  21%
# pillow-11.0.0        | 39.8 MB   | #8                                    |   5%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   |                                       |   0%
#
#
# qt-main-5.15.15      | 48.1 MB   | #########8                            |  27%
# pillow-11.0.0        | 39.8 MB   | ##5                                   |   7%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | 2                                     |   1%
#
#
# libllvm17-17.0.6     | 23.7 MB   | #######################6              |  64%
#
# qt-main-5.15.15      | 48.1 MB   | ###########9                          |  32%
# pillow-11.0.0        | 39.8 MB   | ###4                                  |   9%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | 5                                     |   1%
#
#
# qt-main-5.15.15      | 48.1 MB   | ##############2                       |  39%
# pillow-11.0.0        | 39.8 MB   | ####9                                 |  13%
#
#
# libllvm17-17.0.6     | 23.7 MB   | ################################9     |  89%
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ################4                     |  44%
# pillow-11.0.0        | 39.8 MB   | ######3                               |  17%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | #2                                    |   3%
#
#
# qt-main-5.15.15      | 48.1 MB   | ###################                   |  51%
#
#
#
#
#
#
#
# python-3.13.1        | 12.2 MB   |                                       |   0%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   |                                       |   0%
# pillow-11.0.0        | 39.8 MB   | #######9                              |  22%
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | #####################1                |  57%
#
#
#
#
#
#
#
# python-3.13.1        | 12.2 MB   | #####2                                |  14%
# pillow-11.0.0        | 39.8 MB   | #########9                            |  27%
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ########################2             |  66%
#
#
#
#
#
#
#
# python-3.13.1        | 12.2 MB   | ###############6                      |  42%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | 2                                     |   1%
# pillow-11.0.0        | 39.8 MB   | ###########7                          |  32%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | ###9                                  |  11%
#
#
# libllvm17-17.0.6     | 23.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ##########################5           |  72%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | 4                                     |   1%
# pillow-11.0.0        | 39.8 MB   | #############3                        |  36%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | #####4                                |  15%
#
#
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ############################8         |  78%
# pillow-11.0.0        | 39.8 MB   | ###############3                      |  41%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | 5                                     |   2%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | #######6                              |  21%
#
#
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ###############################2      |  84%
# pillow-11.0.0        | 39.8 MB   | #################2                    |  47%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | ###########4                          |  31%
#
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ##################################    |  92%
# pillow-11.0.0        | 39.8 MB   | ###################5                  |  53%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | ###############6                      |  42%
#
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ####################################7 |  99%
# pillow-11.0.0        | 39.8 MB   | #####################7                |  59%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   |                                       |   0%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | ######################6               |  61%
#
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.3 MB   |                                       |   0%
# pillow-11.0.0        | 39.8 MB   | ########################3             |  66%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | ###########################4          |  74%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | 7                                     |   2%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.3 MB   | ########7                             |  24%
# pillow-11.0.0        | 39.8 MB   | ##########################5           |  72%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | #################################2    |  90%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | #5                                    |   4%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.3 MB   | ###################5                  |  53%
# pillow-11.0.0        | 39.8 MB   | ############################6         |  77%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ##4                                   |   7%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ####5                                 |  12%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.3 MB   | ################################3     |  87%
# pillow-11.0.0        | 39.8 MB   | ###############################       |  84%
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ###4                                  |   9%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ######3                               |  17%
# pillow-11.0.0        | 39.8 MB   | ##################################4   |  93%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | #####4                                |  15%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ########7                             |  24%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | #######3                              |  20%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ############                          |  33%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-18.1.0      | 5.2 MB    | 1                                     |   0%
# pillow-11.0.0        | 39.8 MB   | ##################################### | 100%
# pillow-11.0.0        | 39.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | #########5                            |  26%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ################1                     |  44%
#
#
#
#
#
#
#
# python-3.13.1        | 12.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 4.7 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-18.1.0      | 5.2 MB    | ###################5                  |  53%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ############2                         |  33%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 4.7 MB    | ##################6                   |  50%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-18.1.0      | 5.2 MB    | ##################################### | 100%
#
#
#
#
#
# mysql-server-9.0.1   | 16.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 4.7 MB    | ##################################### | 100%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ########################3             |  66%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ###############3                      |  42%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    | ###############9                      |  43%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | #############################8        |  81%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    | ######################2               |  60%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ####################################7 |  99%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ########################2             |  65%
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 3.7 MB    | 1                                     |   0%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.2 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | #########################4            |  69%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ##################################9   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    | #####1                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.2 MB    | ############################4         |  77%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.4        | 3.0 MB    | 1                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.7           | 2.4 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.7           | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.3 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.4        | 3.0 MB    | ################################3     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.4        | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    | ###################4                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-18.1.0      | 5.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libarrow-18.1.0      | 5.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.7 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    | ###########################9          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.7 MB    | ####9                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.7 MB    | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 4.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 4.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.7 MB    | ##############7                       |  40%
# pillow-11.0.0        | 39.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.7 MB    | ####################1                 |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.7 MB    | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libclang13-19.1.7    | 8.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libclang-cpp17-17.0. | 12.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.7           | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.7           | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.6.4        | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-9.0.1   | 4.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt-main-5.15.15      | 48.1 MB   | ##################################### | 100%
#
#
#
#
#
#
# libboost-headers-1.8 | 13.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install matplotlib cartopy
# Out:
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 26.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - cartopy
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cartopy-0.25.0             |np2py313h86417c3_3         1.5 MB  conda-forge
#     geos-3.14.1                |       ha834cd8_0         1.5 MB  conda-forge
#     gtest-1.16.0               |       ha393de7_0         366 KB  conda-forge
#     proj-9.6.0                 |       h1318a7e_0         2.6 MB  conda-forge
#     pyproj-3.7.1               |  py313h84bd6f1_1         508 KB  conda-forge
#     pyshp-3.1.6                |     pyhcf101f3_0         501 KB  conda-forge
#     shapely-2.1.2              |  py313h2c9f329_3         598 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         7.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cartopy            conda-forge/osx-arm64::cartopy-0.25.0-np2py313h86417c3_3
#   geos               conda-forge/osx-arm64::geos-3.14.1-ha834cd8_0
#   gtest              conda-forge/osx-arm64::gtest-1.16.0-ha393de7_0
#   proj               conda-forge/osx-arm64::proj-9.6.0-h1318a7e_0
#   pyproj             conda-forge/osx-arm64::pyproj-3.7.1-py313h84bd6f1_1
#   pyshp              conda-forge/noarch::pyshp-3.1.6-pyhcf101f3_0
#   shapely            conda-forge/osx-arm64::shapely-2.1.2-py313h2c9f329_3
#
#
#
# Downloading and Extracting Packages:
# proj-9.6.0           | 2.6 MB    |                                       |   0%
# cartopy-0.25.0       | 1.5 MB    |                                       |   0%
#
# geos-3.14.1          | 1.5 MB    |                                       |   0%
#
#
# shapely-2.1.2        | 598 KB    |                                       |   0%
#
#
#
# pyproj-3.7.1         | 508 KB    |                                       |   0%
#
#
#
#
# pyshp-3.1.6          | 501 KB    |                                       |   0%
#
#
#
#
#
# gtest-1.16.0         | 366 KB    |                                       |   0%
#
#
# shapely-2.1.2        | 598 KB    | ##################################### | 100%
# cartopy-0.25.0       | 1.5 MB    | ###################################9  |  97%
#
# geos-3.14.1          | 1.5 MB    | ####################################  |  98%
# cartopy-0.25.0       | 1.5 MB    | ##################################### | 100%
#
#
#
#
# pyshp-3.1.6          | 501 KB    | #1                                    |   3%
#
# geos-3.14.1          | 1.5 MB    | ##################################### | 100%
#
#
#
#
# pyshp-3.1.6          | 501 KB    | ##################################### | 100%
#
#
# shapely-2.1.2        | 598 KB    | ##################################### | 100%
#
#
# shapely-2.1.2        | 598 KB    | ##################################### | 100%
# cartopy-0.25.0       | 1.5 MB    | ##################################### | 100%
#
#
#
#
# pyshp-3.1.6          | 501 KB    | ##################################### | 100%
#
#
#
#
# pyshp-3.1.6          | 501 KB    | ##################################### | 100%
#
#
#
# pyproj-3.7.1         | 508 KB    | #1                                    |   3%
#
#
#
# pyproj-3.7.1         | 508 KB    | ##################################### | 100%
#
#
#
#
#
# gtest-1.16.0         | 366 KB    | #6                                    |   4%
#
# geos-3.14.1          | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
# gtest-1.16.0         | 366 KB    | ##################################### | 100%
#
#
#
# pyproj-3.7.1         | 508 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
